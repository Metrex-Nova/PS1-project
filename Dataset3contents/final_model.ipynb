# %% [markdown]
# ## Parameters affecting the loan interest rates for applicants based on their personal information

# %% [markdown]
# ### Importing Data and packages:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('loan_data_train.csv')
df.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0  79542.0            25000                      25000   60 months
# 1  75473.0            19750                      19750   60 months
# 2  67265.0             2100                       2100   36 months
# 3  80167.0            28000                      28000   36 months
# 4  17240.0            24250                   17431.82   60 months
#
#          Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0  debt_consolidation               27.56%    VA       MORTGAGE
# 1  debt_consolidation               13.39%    NY       MORTGAGE
# 2      major_purchase                3.50%    LA            OWN
# 3         credit_card               19.62%    NV       MORTGAGE
# 4         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 0         8606.56    720-724                11                    15210
# 1         6737.50    710-714                14                    19070
# 2         1000.00    690-694                13                      893
# 3         7083.33    710-714                12                    38194
# 4         5833.33    730-734                 6                    31061
#
#    Inquiries.in.the.Last.6.Months Employment.Length Interest.Rate
# 0                             3.0           5 years        18.49%
# 1                             3.0           4 years        17.27%
# 2                             1.0          < 1 year        14.33%
# 3                             1.0         10+ years        16.29%
# 4                             2.0         10+ years        12.23%

# %% [markdown]
# ### Modify columns name

# %%
df.columns = df.columns.str.replace(".","_")
df.columns
# Out:
# Index(['ID', 'Amount_Requested', 'Amount_Funded_By_Investors', 'Loan_Length',
#        'Loan_Purpose', 'Debt_To_Income_Ratio', 'State', 'Home_Ownership',
#        'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length', 'Interest_Rate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2199 non-null   float64
#  1   Amount_Requested                2199 non-null   object
#  2   Amount_Funded_By_Investors      2199 non-null   object
#  3   Loan_Length                     2199 non-null   object
#  4   Loan_Purpose                    2199 non-null   object
#  5   Debt_To_Income_Ratio            2199 non-null   object
#  6   State                           2199 non-null   object
#  7   Home_Ownership                  2199 non-null   object
#  8   Monthly_Income                  2197 non-null   float64
#  9   FICO_Range                      2200 non-null   object
#  10  Open_CREDIT_Lines               2196 non-null   object
#  11  Revolving_CREDIT_Balance        2197 non-null   object
#  12  Inquiries_in_the_Last_6_Months  2197 non-null   float64
#  13  Employment_Length               2131 non-null   object
#  14  Interest_Rate                   2200 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 257.9+ KB

# %%
df.isnull().sum()
# Out:
# ID                                 1
# Amount_Requested                   1
# Amount_Funded_By_Investors         1
# Loan_Length                        1
# Loan_Purpose                       1
# Debt_To_Income_Ratio               1
# State                              1
# Home_Ownership                     1
# Monthly_Income                     3
# FICO_Range                         0
# Open_CREDIT_Lines                  4
# Revolving_CREDIT_Balance           3
# Inquiries_in_the_Last_6_Months     3
# Employment_Length                 69
# Interest_Rate                      0
# dtype: int64

# %%
df['Employment_Length'].mode()[0]
# Out:
# '10+ years'

# %%
df['Employment_Length']=df['Employment_Length'].fillna(df['Employment_Length'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2199 non-null   float64
#  1   Amount_Requested                2199 non-null   object
#  2   Amount_Funded_By_Investors      2199 non-null   object
#  3   Loan_Length                     2199 non-null   object
#  4   Loan_Purpose                    2199 non-null   object
#  5   Debt_To_Income_Ratio            2199 non-null   object
#  6   State                           2199 non-null   object
#  7   Home_Ownership                  2199 non-null   object
#  8   Monthly_Income                  2197 non-null   float64
#  9   FICO_Range                      2200 non-null   object
#  10  Open_CREDIT_Lines               2196 non-null   object
#  11  Revolving_CREDIT_Balance        2197 non-null   object
#  12  Inquiries_in_the_Last_6_Months  2197 non-null   float64
#  13  Employment_Length               2200 non-null   object
#  14  Interest_Rate                   2200 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 257.9+ KB

# %%
df.dropna(axis=0 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2186 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2186 non-null   float64
#  1   Amount_Requested                2186 non-null   object
#  2   Amount_Funded_By_Investors      2186 non-null   object
#  3   Loan_Length                     2186 non-null   object
#  4   Loan_Purpose                    2186 non-null   object
#  5   Debt_To_Income_Ratio            2186 non-null   object
#  6   State                           2186 non-null   object
#  7   Home_Ownership                  2186 non-null   object
#  8   Monthly_Income                  2186 non-null   float64
#  9   FICO_Range                      2186 non-null   object
#  10  Open_CREDIT_Lines               2186 non-null   object
#  11  Revolving_CREDIT_Balance        2186 non-null   object
#  12  Inquiries_in_the_Last_6_Months  2186 non-null   float64
#  13  Employment_Length               2186 non-null   object
#  14  Interest_Rate                   2186 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 273.2+ KB

# %% [markdown]
# ## changing datatypes

# %%
df['Amount_Requested'] = pd.to_numeric(df['Amount_Requested'],errors = 'coerce')
df['Amount_Funded_By_Investors'] = pd.to_numeric(df['Amount_Funded_By_Investors'],errors = 'coerce')
df['Open_CREDIT_Lines'] = pd.to_numeric(df['Open_CREDIT_Lines'],errors = 'coerce')
df['Revolving_CREDIT_Balance'] = pd.to_numeric(df['Revolving_CREDIT_Balance'],errors = 'coerce')
df['Inquiries_in_the_Last_6_Months'] = pd.to_numeric(df['Inquiries_in_the_Last_6_Months'],errors = 'coerce')

# %%
df.head()
# Out:
#         ID  Amount_Requested  Amount_Funded_By_Investors Loan_Length  \
# 0  79542.0           25000.0                    25000.00   60 months
# 1  75473.0           19750.0                    19750.00   60 months
# 2  67265.0            2100.0                     2100.00   36 months
# 3  80167.0           28000.0                    28000.00   36 months
# 4  17240.0           24250.0                    17431.82   60 months
#
#          Loan_Purpose Debt_To_Income_Ratio State Home_Ownership  \
# 0  debt_consolidation               27.56%    VA       MORTGAGE
# 1  debt_consolidation               13.39%    NY       MORTGAGE
# 2      major_purchase                3.50%    LA            OWN
# 3         credit_card               19.62%    NV       MORTGAGE
# 4         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly_Income FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         8606.56    720-724               11.0                   15210.0
# 1         6737.50    710-714               14.0                   19070.0
# 2         1000.00    690-694               13.0                     893.0
# 3         7083.33    710-714               12.0                   38194.0
# 4         5833.33    730-734                6.0                   31061.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length Interest_Rate
# 0                             3.0           5 years        18.49%
# 1                             3.0           4 years        17.27%
# 2                             1.0          < 1 year        14.33%
# 3                             1.0         10+ years        16.29%
# 4                             2.0         10+ years        12.23%

# %%
df['Interest_Rate']=df['Interest_Rate'].str.replace('%','').astype('float64')

# %%
df['Loan_Length']=df['Loan_Length'].str.split(' ').apply(lambda x : x[0]).tolist()

# %%
df['Loan_Length'] = pd.to_numeric(df['Loan_Length'],errors = 'coerce')

# %%
df['Debt_To_Income_Ratio']=df['Debt_To_Income_Ratio'].str.replace('%','').astype('float64')

# %%
df.head()
# Out:
#         ID  Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0  79542.0           25000.0                    25000.00         60.0
# 1  75473.0           19750.0                    19750.00         60.0
# 2  67265.0            2100.0                     2100.00         36.0
# 3  80167.0           28000.0                    28000.00         36.0
# 4  17240.0           24250.0                    17431.82         60.0
#
#          Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0  debt_consolidation                 27.56    VA       MORTGAGE
# 1  debt_consolidation                 13.39    NY       MORTGAGE
# 2      major_purchase                  3.50    LA            OWN
# 3         credit_card                 19.62    NV       MORTGAGE
# 4         credit_card                 23.79    OH       MORTGAGE
#
#    Monthly_Income FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         8606.56    720-724               11.0                   15210.0
# 1         6737.50    710-714               14.0                   19070.0
# 2         1000.00    690-694               13.0                     893.0
# 3         7083.33    710-714               12.0                   38194.0
# 4         5833.33    730-734                6.0                   31061.0
#
#    Inquiries_in_the_Last_6_Months Employment_Length  Interest_Rate
# 0                             3.0           5 years          18.49
# 1                             3.0           4 years          17.27
# 2                             1.0          < 1 year          14.33
# 3                             1.0         10+ years          16.29
# 4                             2.0         10+ years          12.23

# %%
df.Employment_Length = df.Employment_Length.str.replace('<','')
df.Employment_Length = df.Employment_Length.str.replace('years','')
df.Employment_Length = df.Employment_Length.str.replace('year','')
df.Employment_Length = df.Employment_Length.str.replace('+','')
df['Employment_Length'] = pd.to_numeric(df['Employment_Length'],errors = 'coerce')

# %%
df[['Min_Fic','Max_Fic']] = df.FICO_Range.str.split('-',expand=True).astype('float64')
df['Fico_Mean'] = (df.Min_Fic + df.Max_Fic)/2

display(df,df.dtypes)
# Out:
#            ID  Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0     79542.0           25000.0                    25000.00         60.0
# 1     75473.0           19750.0                    19750.00         60.0
# 2     67265.0            2100.0                     2100.00         36.0
# 3     80167.0           28000.0                    28000.00         36.0
# 4     17240.0           24250.0                    17431.82         60.0
# ...       ...               ...                         ...          ...
# 2195  74047.0           30000.0                    30000.00         60.0
# 2196  63768.0            4200.0                     4200.00         60.0
# 2197  94545.0           19800.0                    19775.00         60.0
# 2198  53635.0           18000.0                    18000.00         60.0
# 2199  67953.0            7550.0                     7550.00         36.0
#
#             Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0     debt_consolidation                 27.56    VA       MORTGAGE
# 1     debt_consolidation                 13.39    NY       MORTGAGE
# 2         major_purchase                  3.50    LA            OWN
# 3            credit_card                 19.62    NV       MORTGAGE
# 4            credit_card                 23.79    OH       MORTGAGE
# ...                  ...                   ...   ...            ...
# 2195               other                 12.10    IL       MORTGAGE
# 2196                 car                 14.16    NJ           RENT
# 2197  debt_consolidation                 15.03    IL       MORTGAGE
# 2198         credit_card                 11.63    CA           RENT
# 2199  debt_consolidation                  3.83    CA       MORTGAGE
#
#       Monthly_Income FICO_Range  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0            8606.56    720-724               11.0                   15210.0
# 1            6737.50    710-714               14.0                   19070.0
# 2            1000.00    690-694               13.0                     893.0
# 3            7083.33    710-714               12.0                   38194.0
# 4            5833.33    730-734                6.0                   31061.0
# ...              ...        ...                ...                       ...
# 2195         7083.33    675-679               16.0                   17969.0
# 2196         3850.00    700-704                4.0                    5718.0
# 2197         6666.67    675-679               10.0                   46879.0
# 2198         9051.83    670-674                5.0                   32394.0
# 2199         8333.33    710-714               10.0                   10204.0
#
#       Inquiries_in_the_Last_6_Months  Employment_Length  Interest_Rate  \
# 0                                3.0                5.0          18.49
# 1                                3.0                4.0          17.27
# 2                                1.0                1.0          14.33
# 3                                1.0               10.0          16.29
# 4                                2.0               10.0          12.23
# ...                              ...                ...            ...
# 2195                             1.0               10.0          23.28
# 2196                             0.0                2.0          14.33
# 2197                             3.0                6.0          15.31
# 2198                             2.0                4.0          20.99
# 2199                             0.0                2.0          10.16
#
#       Min_Fic  Max_Fic  Fico_Mean
# 0       720.0    724.0      722.0
# 1       710.0    714.0      712.0
# 2       690.0    694.0      692.0
# 3       710.0    714.0      712.0
# 4       730.0    734.0      732.0
# ...       ...      ...        ...
# 2195    675.0    679.0      677.0
# 2196    700.0    704.0      702.0
# 2197    675.0    679.0      677.0
# 2198    670.0    674.0      672.0
# 2199    710.0    714.0      712.0
#
# [2186 rows x 18 columns]
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                 float64
# Revolving_CREDIT_Balance          float64
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                 float64
# Interest_Rate                     float64
# Min_Fic                           float64
# Max_Fic                           float64
# Fico_Mean                         float64
# dtype: object

# %%
## drop insignificant columns
df = df.drop(['ID','FICO_Range','Min_Fic','Max_Fic'],axis=1)
df.head()
# Out:
#    Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0           25000.0                    25000.00         60.0
# 1           19750.0                    19750.00         60.0
# 2            2100.0                     2100.00         36.0
# 3           28000.0                    28000.00         36.0
# 4           24250.0                    17431.82         60.0
#
#          Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0  debt_consolidation                 27.56    VA       MORTGAGE
# 1  debt_consolidation                 13.39    NY       MORTGAGE
# 2      major_purchase                  3.50    LA            OWN
# 3         credit_card                 19.62    NV       MORTGAGE
# 4         credit_card                 23.79    OH       MORTGAGE
#
#    Monthly_Income  Open_CREDIT_Lines  Revolving_CREDIT_Balance  \
# 0         8606.56               11.0                   15210.0
# 1         6737.50               14.0                   19070.0
# 2         1000.00               13.0                     893.0
# 3         7083.33               12.0                   38194.0
# 4         5833.33                6.0                   31061.0
#
#    Inquiries_in_the_Last_6_Months  Employment_Length  Interest_Rate  Fico_Mean
# 0                             3.0                5.0          18.49      722.0
# 1                             3.0                4.0          17.27      712.0
# 2                             1.0                1.0          14.33      692.0
# 3                             1.0               10.0          16.29      712.0
# 4                             2.0               10.0          12.23      732.0

# %%
df.Home_Ownership.unique()
# Out:
# array(['MORTGAGE', 'OWN', 'RENT', 'OTHER'], dtype=object)

# %%
df.State.unique()
# Out:
# array(['VA', 'NY', 'LA', 'NV', 'OH', 'CA', 'IL', 'NC', 'NJ', 'WA', 'CT',
#        'AK', 'CO', 'MA', 'TX', 'VT', 'OK', 'FL', 'NH', 'GA', 'MN', 'MD',
#        'WY', 'PA', 'AL', 'AZ', 'SC', 'MI', 'OR', 'RI', 'NM', 'MO', 'WI',
#        'KY', 'UT', 'AR', 'WV', 'DE', 'MT', 'KS', 'DC', 'SD', 'HI', 'IN',
#        'MS', '.'], dtype=object)

# %%
df.Loan_Purpose.unique()
# Out:
# array(['debt_consolidation', 'major_purchase', 'credit_card',
#        'small_business', 'home_improvement', 'other', 'car', 'moving',
#        'house', 'educational', 'vacation', 'wedding', 'medical',
#        'renewable_energy'], dtype=object)

# %%
## Seperating Numerical variables and Categorical variables:
Numeric_data = df.columns[df.dtypes != 'object']
Cat_data = df.columns[df.dtypes == 'object']

Num_Vars = df[Numeric_data]
Cat_Vars = df[Cat_data]
Y_Var = df[['Interest_Rate']]
display('Num_Vars',Num_Vars.head(3),Num_Vars.shape,'Cat_Vars',Cat_Vars.head(3),Cat_Vars.shape,'Y_Var',Y_Var.head(3),Y_Var.shape)
# Out:
# 'Num_Vars'
#    Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0           25000.0                     25000.0         60.0
# 1           19750.0                     19750.0         60.0
# 2            2100.0                      2100.0         36.0
#
#    Debt_To_Income_Ratio  Monthly_Income  Open_CREDIT_Lines  \
# 0                 27.56         8606.56               11.0
# 1                 13.39         6737.50               14.0
# 2                  3.50         1000.00               13.0
#
#    Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  \
# 0                   15210.0                             3.0
# 1                   19070.0                             3.0
# 2                     893.0                             1.0
#
#    Employment_Length  Interest_Rate  Fico_Mean
# 0                5.0          18.49      722.0
# 1                4.0          17.27      712.0
# 2                1.0          14.33      692.0
# (2186, 11)
# 'Cat_Vars'
#          Loan_Purpose State Home_Ownership
# 0  debt_consolidation    VA       MORTGAGE
# 1  debt_consolidation    NY       MORTGAGE
# 2      major_purchase    LA            OWN
# (2186, 3)
# 'Y_Var'
#    Interest_Rate
# 0          18.49
# 1          17.27
# 2          14.33
# (2186, 1)

# %%
Num_Vars = Num_Vars.drop('Interest_Rate',axis=1)
Num_Vars.head(3)
# Out:
#    Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0           25000.0                     25000.0         60.0
# 1           19750.0                     19750.0         60.0
# 2            2100.0                      2100.0         36.0
#
#    Debt_To_Income_Ratio  Monthly_Income  Open_CREDIT_Lines  \
# 0                 27.56         8606.56               11.0
# 1                 13.39         6737.50               14.0
# 2                  3.50         1000.00               13.0
#
#    Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  \
# 0                   15210.0                             3.0
# 1                   19070.0                             3.0
# 2                     893.0                             1.0
#
#    Employment_Length  Fico_Mean
# 0                5.0      722.0
# 1                4.0      712.0
# 2                1.0      692.0

# %% [markdown]
# ### Missing value and Outlier treatment:

# %%
def outlier_missing_treatment(x):
    x = np.clip(x, a_min = x.quantile(0.01), a_max = x.quantile(0.99))
    x = x.fillna(x.median())
    return(x)

# %%
Num_Vars = Num_Vars.apply(outlier_missing_treatment)

# %%
def Mode_treatment(x):
    x = x.fillna(x.mode)
    return(x)

# %%
Cat_Vars = Cat_Vars.apply(Mode_treatment)

# %% [markdown]
# ### Creating dummy variables of Cateforical Variables:

# %%
dummy_vars = pd.get_dummies(Cat_Vars, drop_first=True)
dummy_vars
# Out:
#       Loan_Purpose_credit_card  Loan_Purpose_debt_consolidation  \
# 0                        False                             True
# 1                        False                             True
# 2                        False                            False
# 3                         True                            False
# 4                         True                            False
# ...                        ...                              ...
# 2195                     False                            False
# 2196                     False                            False
# 2197                     False                             True
# 2198                      True                            False
# 2199                     False                             True
#
#       Loan_Purpose_educational  Loan_Purpose_home_improvement  \
# 0                        False                          False
# 1                        False                          False
# 2                        False                          False
# 3                        False                          False
# 4                        False                          False
# ...                        ...                            ...
# 2195                     False                          False
# 2196                     False                          False
# 2197                     False                          False
# 2198                     False                          False
# 2199                     False                          False
#
#       Loan_Purpose_house  Loan_Purpose_major_purchase  Loan_Purpose_medical  \
# 0                  False                        False                 False
# 1                  False                        False                 False
# 2                  False                         True                 False
# 3                  False                        False                 False
# 4                  False                        False                 False
# ...                  ...                          ...                   ...
# 2195               False                        False                 False
# 2196               False                        False                 False
# 2197               False                        False                 False
# 2198               False                        False                 False
# 2199               False                        False                 False
#
#       Loan_Purpose_moving  Loan_Purpose_other  Loan_Purpose_renewable_energy  \
# 0                   False               False                          False
# 1                   False               False                          False
# 2                   False               False                          False
# 3                   False               False                          False
# 4                   False               False                          False
# ...                   ...                 ...                            ...
# 2195                False                True                          False
# 2196                False               False                          False
# 2197                False               False                          False
# 2198                False               False                          False
# 2199                False               False                          False
#
#       ...  State_UT  State_VA  State_VT  State_WA  State_WI  State_WV  \
# 0     ...     False      True     False     False     False     False
# 1     ...     False     False     False     False     False     False
# 2     ...     False     False     False     False     False     False
# 3     ...     False     False     False     False     False     False
# 4     ...     False     False     False     False     False     False
# ...   ...       ...       ...       ...       ...       ...       ...
# 2195  ...     False     False     False     False     False     False
# 2196  ...     False     False     False     False     False     False
# 2197  ...     False     False     False     False     False     False
# 2198  ...     False     False     False     False     False     False
# 2199  ...     False     False     False     False     False     False
#
#       State_WY  Home_Ownership_OTHER  Home_Ownership_OWN  Home_Ownership_RENT
# 0        False                 False               False                False
# 1        False                 False               False                False
# 2        False                 False                True                False
# 3        False                 False               False                False
# 4        False                 False               False                False
# ...        ...                   ...                 ...                  ...
# 2195     False                 False               False                False
# 2196     False                 False               False                 True
# 2197     False                 False               False                False
# 2198     False                 False               False                 True
# 2199     False                 False               False                False
#
# [2186 rows x 61 columns]

# %%
df_final = pd.concat([Num_Vars, dummy_vars, Y_Var], axis=1)

df_final
# Out:
#       Amount_Requested  Amount_Funded_By_Investors  Loan_Length  \
# 0              25000.0                    25000.00         60.0
# 1              19750.0                    19750.00         60.0
# 2               2100.0                     2100.00         36.0
# 3              28000.0                    28000.00         36.0
# 4              24250.0                    17431.82         60.0
# ...                ...                         ...          ...
# 2195           30000.0                    30000.00         60.0
# 2196            4200.0                     4200.00         60.0
# 2197           19800.0                    19775.00         60.0
# 2198           18000.0                    18000.00         60.0
# 2199            7550.0                     7550.00         36.0
#
#       Debt_To_Income_Ratio  Monthly_Income  Open_CREDIT_Lines  \
# 0                    27.56        8606.560               11.0
# 1                    13.39        6737.500               14.0
# 2                     3.50        1404.169               13.0
# 3                    19.62        7083.330               12.0
# 4                    23.79        5833.330                6.0
# ...                    ...             ...                ...
# 2195                 12.10        7083.330               16.0
# 2196                 14.16        3850.000                4.0
# 2197                 15.03        6666.670               10.0
# 2198                 11.63        9051.830                5.0
# 2199                  3.83        8333.330               10.0
#
#       Revolving_CREDIT_Balance  Inquiries_in_the_Last_6_Months  \
# 0                      15210.0                             3.0
# 1                      19070.0                             3.0
# 2                        893.0                             1.0
# 3                      38194.0                             1.0
# 4                      31061.0                             2.0
# ...                        ...                             ...
# 2195                   17969.0                             1.0
# 2196                    5718.0                             0.0
# 2197                   46879.0                             3.0
# 2198                   32394.0                             2.0
# 2199                   10204.0                             0.0
#
#       Employment_Length  Fico_Mean  ...  State_VA  State_VT  State_WA  \
# 0                   5.0      722.0  ...      True     False     False
# 1                   4.0      712.0  ...     False     False     False
# 2                   1.0      692.0  ...     False     False     False
# 3                  10.0      712.0  ...     False     False     False
# 4                  10.0      732.0  ...     False     False     False
# ...                 ...        ...  ...       ...       ...       ...
# 2195               10.0      677.0  ...     False     False     False
# 2196                2.0      702.0  ...     False     False     False
# 2197                6.0      677.0  ...     False     False     False
# 2198                4.0      672.0  ...     False     False     False
# 2199                2.0      712.0  ...     False     False     False
#
#       State_WI  State_WV  State_WY  Home_Ownership_OTHER  Home_Ownership_OWN  \
# 0        False     False     False                 False               False
# 1        False     False     False                 False               False
# 2        False     False     False                 False                True
# 3        False     False     False                 False               False
# 4        False     False     False                 False               False
# ...        ...       ...       ...                   ...                 ...
# 2195     False     False     False                 False               False
# 2196     False     False     False                 False               False
# 2197     False     False     False                 False               False
# 2198     False     False     False                 False               False
# 2199     False     False     False                 False               False
#
#       Home_Ownership_RENT  Interest_Rate
# 0                   False          18.49
# 1                   False          17.27
# 2                   False          14.33
# 3                   False          16.29
# 4                   False          12.23
# ...                   ...            ...
# 2195                False          23.28
# 2196                 True          14.33
# 2197                False          15.31
# 2198                 True          20.99
# 2199                False          10.16
#
# [2186 rows x 72 columns]

# %%
plt.figure(figsize=(10,5))
sns.distplot(df_final.Interest_Rate)
plt.show()

# %% [markdown]
# ### Section 2: Feature Reduction

# %%
target = df_final['Interest_Rate']
features = df_final[df_final.columns.difference(['Interest_Rate'])]

display(target, features)
# Out:
# 0       18.49
# 1       17.27
# 2       14.33
# 3       16.29
# 4       12.23
#         ...
# 2195    23.28
# 2196    14.33
# 2197    15.31
# 2198    20.99
# 2199    10.16
# Name: Interest_Rate, Length: 2186, dtype: float64
#       Amount_Funded_By_Investors  Amount_Requested  Debt_To_Income_Ratio  \
# 0                       25000.00           25000.0                 27.56
# 1                       19750.00           19750.0                 13.39
# 2                        2100.00            2100.0                  3.50
# 3                       28000.00           28000.0                 19.62
# 4                       17431.82           24250.0                 23.79
# ...                          ...               ...                   ...
# 2195                    30000.00           30000.0                 12.10
# 2196                     4200.00            4200.0                 14.16
# 2197                    19775.00           19800.0                 15.03
# 2198                    18000.00           18000.0                 11.63
# 2199                     7550.00            7550.0                  3.83
#
#       Employment_Length  Fico_Mean  Home_Ownership_OTHER  Home_Ownership_OWN  \
# 0                   5.0      722.0                 False               False
# 1                   4.0      712.0                 False               False
# 2                   1.0      692.0                 False                True
# 3                  10.0      712.0                 False               False
# 4                  10.0      732.0                 False               False
# ...                 ...        ...                   ...                 ...
# 2195               10.0      677.0                 False               False
# 2196                2.0      702.0                 False               False
# 2197                6.0      677.0                 False               False
# 2198                4.0      672.0                 False               False
# 2199                2.0      712.0                 False               False
#
#       Home_Ownership_RENT  Inquiries_in_the_Last_6_Months  Loan_Length  ...  \
# 0                   False                             3.0         60.0  ...
# 1                   False                             3.0         60.0  ...
# 2                   False                             1.0         36.0  ...
# 3                   False                             1.0         36.0  ...
# 4                   False                             2.0         60.0  ...
# ...                   ...                             ...          ...  ...
# 2195                False                             1.0         60.0  ...
# 2196                 True                             0.0         60.0  ...
# 2197                False                             3.0         60.0  ...
# 2198                 True                             2.0         60.0  ...
# 2199                False                             0.0         36.0  ...
#
#       State_SC  State_SD  State_TX  State_UT  State_VA  State_VT  State_WA  \
# 0        False     False     False     False      True     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195     False     False     False     False     False     False     False
# 2196     False     False     False     False     False     False     False
# 2197     False     False     False     False     False     False     False
# 2198     False     False     False     False     False     False     False
# 2199     False     False     False     False     False     False     False
#
#       State_WI  State_WV  State_WY
# 0        False     False     False
# 1        False     False     False
# 2        False     False     False
# 3        False     False     False
# 4        False     False     False
# ...        ...       ...       ...
# 2195     False     False     False
# 2196     False     False     False
# 2197     False     False     False
# 2198     False     False     False
# 2199     False     False     False
#
# [2186 rows x 71 columns]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

rfe = RFE(lm, n_features_to_select=10)

rfe = rfe.fit(features,target)
rfe
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=10)

# %%
RFE_imp_vars = features.columns[rfe.get_support()]
list(RFE_imp_vars)
# Out:
# ['Home_Ownership_OTHER',
#  'Loan_Purpose_house',
#  'Loan_Purpose_moving',
#  'Loan_Purpose_renewable_energy',
#  'State_AK',
#  'State_HI',
#  'State_LA',
#  'State_MT',
#  'State_SD',
#  'State_VT']

# %%
from sklearn.feature_selection import f_regression

f_reg, p_val = f_regression(features,target)

f_reg = pd.Series(f_reg)
p_val = pd.Series(p_val)
cols = pd.Series(features.columns)

# %%
f_reg_res = pd.concat([cols,f_reg,p_val],axis=1)
f_reg_res.columns = ['cols','F_values','p_values']
f_reg_res
# Out:
#                           cols     F_values      p_values
# 0   Amount_Funded_By_Investors   279.751224  3.493429e-59
# 1             Amount_Requested   271.853637  1.178647e-57
# 2         Debt_To_Income_Ratio    73.991827  1.472001e-17
# 3            Employment_Length     2.887689  8.940126e-02
# 4                    Fico_Mean  2237.147784  0.000000e+00
# ..                         ...          ...           ...
# 66                    State_VT     6.745034  9.464007e-03
# 67                    State_WA     0.008284  9.274859e-01
# 68                    State_WI     0.698737  4.032999e-01
# 69                    State_WV     0.060388  8.059063e-01
# 70                    State_WY     0.039054  8.433607e-01
#
# [71 rows x 3 columns]

# %%
top_10_f_reg = f_reg_res.sort_values(by=['F_values'],ascending=False).head(10)

list(top_10_f_reg.cols)

['Home_Ownership_OTHER',
 'Loan_Purpose_house',
 'Loan_Purpose_moving',
 'Loan_Purpose_renewable_energy',
 'State_AK',
 'State_HI',
 'State_LA',
 'State_MT',
 'State_SD',
 'State_VT']
# Out:
# ['Home_Ownership_OTHER',
#  'Loan_Purpose_house',
#  'Loan_Purpose_moving',
#  'Loan_Purpose_renewable_energy',
#  'State_AK',
#  'State_HI',
#  'State_LA',
#  'State_MT',
#  'State_SD',
#  'State_VT']

# %%
from sklearn.feature_selection import SelectKBest,f_classif ,chi2

selector = SelectKBest(f_classif, k=10)

selector.fit(features, target)
# Out:
# SelectKBest()

# %%
K_Best_10 = features.columns[selector.get_support()]

list(K_Best_10)
# Out:
# ['Amount_Funded_By_Investors',
#  'Amount_Requested',
#  'Fico_Mean',
#  'Inquiries_in_the_Last_6_Months',
#  'Loan_Length',
#  'Loan_Purpose_educational',
#  'State_IN',
#  'State_MO',
#  'State_MS',
#  'State_VT']

# %% [markdown]
# ### Correlation Method:

# %%
df_final.corrwith(df_final.Interest_Rate)
# Out:
# Amount_Requested              0.332710
# Amount_Funded_By_Investors    0.336967
# Loan_Length                   0.426056
# Debt_To_Income_Ratio          0.181022
# Monthly_Income                0.038563
#                                 ...
# State_WY                      0.004229
# Home_Ownership_OTHER          0.035582
# Home_Ownership_OWN           -0.024308
# Home_Ownership_RENT           0.089989
# Interest_Rate                 1.000000
# Length: 72, dtype: float64

# %%
column_names = pd.Series(list(df_final.corrwith(df_final.Interest_Rate).index),name='Column_Names')
r_values =  pd.Series(list(df_final.corrwith(df_final.Interest_Rate)),name='r_values')

corr = pd.concat([column_names,r_values],axis=1)

# %%
corr_10 = corr.sort_values(by=['r_values'],ascending=False).head(10)

list(corr_10['Column_Names'])
# Out:
# ['Interest_Rate',
#  'Loan_Length',
#  'Amount_Funded_By_Investors',
#  'Amount_Requested',
#  'Debt_To_Income_Ratio',
#  'Inquiries_in_the_Last_6_Months',
#  'Loan_Purpose_debt_consolidation',
#  'Home_Ownership_RENT',
#  'Open_CREDIT_Lines',
#  'Revolving_CREDIT_Balance']

# %% [markdown]
# ### Final Variables

# %%
Final_Vars = {
 'Home_Ownership_OTHER',
 'Loan_Purpose_credit_card',
 'Loan_Purpose_debt_consolidation',
 'Loan_Purpose_house',
 'Loan_Purpose_moving',
 'Loan_Purpose_other',
 'Loan_Purpose_small_business',
 'State_MT',
 'State_SD',
 'Loan_Length',
 'Amount_Funded_By_Investors',
 'Amount_Requested',
 'Debt_To_Income_Ratio',
 'Inquiries_in_the_Last_6_Months',
 'Loan_Purpose_debt_consolidation',
 'Loan_Purpose_major_purchase',
 'Loan_Purpose_home_improvement',
 'Home_Ownership_RENT',
'Amount_Funded_By_Investors',
 'Fico_Mean',
 'Home_Ownership_OTHER',
 'Inquiries_in_the_Last_6_Months',
 'Loan_Length',
 'Loan_Purpose_educational',
 'State_IN',
 'State_MS',
 'Loan_Length',
 'Amount_Funded_By_Investors',
 'Amount_Requested',
 'Debt_To_Income_Ratio',
 'Inquiries_in_the_Last_6_Months',
 'Loan_Purpose_debt_consolidation',
 'Loan_Purpose_major_purchase',
 'Loan_Purpose_home_improvement',
 'Home_Ownership_RENT',
 'Revolving_CREDIT_Balance'}

# %%
Final_Vars = list(Final_Vars)

features2 = df_final[Final_Vars]

features2
# Out:
#       State_SD  State_IN  Debt_To_Income_Ratio  State_MT  \
# 0        False     False                 27.56     False
# 1        False     False                 13.39     False
# 2        False     False                  3.50     False
# 3        False     False                 19.62     False
# 4        False     False                 23.79     False
# ...        ...       ...                   ...       ...
# 2195     False     False                 12.10     False
# 2196     False     False                 14.16     False
# 2197     False     False                 15.03     False
# 2198     False     False                 11.63     False
# 2199     False     False                  3.83     False
#
#       Loan_Purpose_educational  Revolving_CREDIT_Balance  \
# 0                        False                   15210.0
# 1                        False                   19070.0
# 2                        False                     893.0
# 3                        False                   38194.0
# 4                        False                   31061.0
# ...                        ...                       ...
# 2195                     False                   17969.0
# 2196                     False                    5718.0
# 2197                     False                   46879.0
# 2198                     False                   32394.0
# 2199                     False                   10204.0
#
#       Loan_Purpose_home_improvement  Home_Ownership_OTHER  \
# 0                             False                 False
# 1                             False                 False
# 2                             False                 False
# 3                             False                 False
# 4                             False                 False
# ...                             ...                   ...
# 2195                          False                 False
# 2196                          False                 False
# 2197                          False                 False
# 2198                          False                 False
# 2199                          False                 False
#
#       Loan_Purpose_moving  State_MS  ...  Loan_Purpose_house  \
# 0                   False     False  ...               False
# 1                   False     False  ...               False
# 2                   False     False  ...               False
# 3                   False     False  ...               False
# 4                   False     False  ...               False
# ...                   ...       ...  ...                 ...
# 2195                False     False  ...               False
# 2196                False     False  ...               False
# 2197                False     False  ...               False
# 2198                False     False  ...               False
# 2199                False     False  ...               False
#
#       Loan_Purpose_debt_consolidation  Fico_Mean  Amount_Funded_By_Investors  \
# 0                                True      722.0                    25000.00
# 1                                True      712.0                    19750.00
# 2                               False      692.0                     2100.00
# 3                               False      712.0                    28000.00
# 4                               False      732.0                    17431.82
# ...                               ...        ...                         ...
# 2195                            False      677.0                    30000.00
# 2196                            False      702.0                     4200.00
# 2197                             True      677.0                    19775.00
# 2198                            False      672.0                    18000.00
# 2199                             True      712.0                     7550.00
#
#       Loan_Purpose_credit_card  Loan_Purpose_major_purchase  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                         True
# 3                         True                        False
# 4                         True                        False
# ...                        ...                          ...
# 2195                     False                        False
# 2196                     False                        False
# 2197                     False                        False
# 2198                      True                        False
# 2199                     False                        False
#
#       Loan_Purpose_small_business  Inquiries_in_the_Last_6_Months  \
# 0                           False                             3.0
# 1                           False                             3.0
# 2                           False                             1.0
# 3                           False                             1.0
# 4                           False                             2.0
# ...                           ...                             ...
# 2195                        False                             1.0
# 2196                        False                             0.0
# 2197                        False                             3.0
# 2198                        False                             2.0
# 2199                        False                             0.0
#
#       Amount_Requested  Loan_Purpose_other
# 0              25000.0               False
# 1              19750.0               False
# 2               2100.0               False
# 3              28000.0               False
# 4              24250.0               False
# ...                ...                 ...
# 2195           30000.0                True
# 2196            4200.0               False
# 2197           19800.0               False
# 2198           18000.0               False
# 2199            7550.0               False
#
# [2186 rows x 22 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices

# %%
# Convert boolean columns to integers (0 and 1)
features2 = features2.astype({col: 'int64' for col in features2.select_dtypes(include='bool').columns})

# %%
# Convert everything to numeric, just in case
features2 = features2.apply(pd.to_numeric, errors='coerce')

# Fill any missing values
features2 = features2.fillna(features2.median())

# Now compute VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["feature"] = features2.columns
vif_data["VIF"] = [variance_inflation_factor(features2.values, i) for i in range(features2.shape[1])]
vif_data
# Out:
#                             feature        VIF
# 0                          State_SD   1.007011
# 1                          State_IN   1.014189
# 2              Debt_To_Income_Ratio   5.667761
# 3                          State_MT   1.010557
# 4          Loan_Purpose_educational   1.120677
# 5          Revolving_CREDIT_Balance   2.461273
# 6     Loan_Purpose_home_improvement   2.135593
# 7              Home_Ownership_OTHER   1.339140
# 8               Loan_Purpose_moving   1.188503
# 9                          State_MS   1.348366
# 10                      Loan_Length  21.638068
# 11              Home_Ownership_RENT   1.976987
# 12               Loan_Purpose_house   1.150621
# 13  Loan_Purpose_debt_consolidation   9.921722
# 14                        Fico_Mean  34.134395
# 15       Amount_Funded_By_Investors  58.144916
# 16         Loan_Purpose_credit_card   4.027599
# 17      Loan_Purpose_major_purchase   1.666963
# 18      Loan_Purpose_small_business   1.633830
# 19   Inquiries_in_the_Last_6_Months   1.668924
# 20                 Amount_Requested  61.419612
# 21               Loan_Purpose_other   2.288376

# %%
features2.dtypes
# Out:
# State_SD                             int64
# State_IN                             int64
# Debt_To_Income_Ratio               float64
# State_MT                             int64
# Loan_Purpose_educational             int64
# Revolving_CREDIT_Balance           float64
# Loan_Purpose_home_improvement        int64
# Home_Ownership_OTHER                 int64
# Loan_Purpose_moving                  int64
# State_MS                             int64
# Loan_Length                        float64
# Home_Ownership_RENT                  int64
# Loan_Purpose_house                   int64
# Loan_Purpose_debt_consolidation      int64
# Fico_Mean                          float64
# Amount_Funded_By_Investors         float64
# Loan_Purpose_credit_card             int64
# Loan_Purpose_major_purchase          int64
# Loan_Purpose_small_business          int64
# Inquiries_in_the_Last_6_Months     float64
# Amount_Requested                   float64
# Loan_Purpose_other                   int64
# dtype: object

# %%
VIF = [variance_inflation_factor(features2.values,i) for i in range(features2.shape[1])]

# %%
VIF = pd.Series(VIF, name = 'VIF')

cols = pd.Series(features2.columns, name='Column_Name')

VIF_res = pd.concat([cols,VIF],axis=1)

VIF_10 = VIF_res.sort_values(by=['VIF']).head(10)

# %%
Final_Vars.append('Interest_Rate')

df_final = df_final[Final_Vars]

df_final
# Out:
#       State_SD  State_IN  Debt_To_Income_Ratio  State_MT  \
# 0        False     False                 27.56     False
# 1        False     False                 13.39     False
# 2        False     False                  3.50     False
# 3        False     False                 19.62     False
# 4        False     False                 23.79     False
# ...        ...       ...                   ...       ...
# 2195     False     False                 12.10     False
# 2196     False     False                 14.16     False
# 2197     False     False                 15.03     False
# 2198     False     False                 11.63     False
# 2199     False     False                  3.83     False
#
#       Loan_Purpose_educational  Revolving_CREDIT_Balance  \
# 0                        False                   15210.0
# 1                        False                   19070.0
# 2                        False                     893.0
# 3                        False                   38194.0
# 4                        False                   31061.0
# ...                        ...                       ...
# 2195                     False                   17969.0
# 2196                     False                    5718.0
# 2197                     False                   46879.0
# 2198                     False                   32394.0
# 2199                     False                   10204.0
#
#       Loan_Purpose_home_improvement  Home_Ownership_OTHER  \
# 0                             False                 False
# 1                             False                 False
# 2                             False                 False
# 3                             False                 False
# 4                             False                 False
# ...                             ...                   ...
# 2195                          False                 False
# 2196                          False                 False
# 2197                          False                 False
# 2198                          False                 False
# 2199                          False                 False
#
#       Loan_Purpose_moving  State_MS  ...  Loan_Purpose_debt_consolidation  \
# 0                   False     False  ...                             True
# 1                   False     False  ...                             True
# 2                   False     False  ...                            False
# 3                   False     False  ...                            False
# 4                   False     False  ...                            False
# ...                   ...       ...  ...                              ...
# 2195                False     False  ...                            False
# 2196                False     False  ...                            False
# 2197                False     False  ...                             True
# 2198                False     False  ...                            False
# 2199                False     False  ...                             True
#
#       Fico_Mean  Amount_Funded_By_Investors  Loan_Purpose_credit_card  \
# 0         722.0                    25000.00                     False
# 1         712.0                    19750.00                     False
# 2         692.0                     2100.00                     False
# 3         712.0                    28000.00                      True
# 4         732.0                    17431.82                      True
# ...         ...                         ...                       ...
# 2195      677.0                    30000.00                     False
# 2196      702.0                     4200.00                     False
# 2197      677.0                    19775.00                     False
# 2198      672.0                    18000.00                      True
# 2199      712.0                     7550.00                     False
#
#       Loan_Purpose_major_purchase  Loan_Purpose_small_business  \
# 0                           False                        False
# 1                           False                        False
# 2                            True                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 2195                        False                        False
# 2196                        False                        False
# 2197                        False                        False
# 2198                        False                        False
# 2199                        False                        False
#
#       Inquiries_in_the_Last_6_Months  Amount_Requested  Loan_Purpose_other  \
# 0                                3.0           25000.0               False
# 1                                3.0           19750.0               False
# 2                                1.0            2100.0               False
# 3                                1.0           28000.0               False
# 4                                2.0           24250.0               False
# ...                              ...               ...                 ...
# 2195                             1.0           30000.0                True
# 2196                             0.0            4200.0               False
# 2197                             3.0           19800.0               False
# 2198                             2.0           18000.0               False
# 2199                             0.0            7550.0               False
#
#       Interest_Rate
# 0             18.49
# 1             17.27
# 2             14.33
# 3             16.29
# 4             12.23
# ...             ...
# 2195          23.28
# 2196          14.33
# 2197          15.31
# 2198          20.99
# 2199          10.16
#
# [2186 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df_final, test_size = 0.3, random_state = 123)

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('Interest_Rate ~ Loan_Purpose_educational + Loan_Purpose_house +State_MS+ Loan_Length+ Fico_Mean+ Loan_Purpose_other+ Loan_Purpose_credit_card+ Home_Ownership_RENT+State_IN+ Loan_Purpose_small_business+ State_SD+Debt_To_Income_Ratio+ Loan_Purpose_debt_consolidation+Home_Ownership_OTHER+ Amount_Requested+ Revolving_CREDIT_Balance+State_MT+ Loan_Purpose_home_improvement+Amount_Funded_By_Investors+ Loan_Purpose_moving+Inquiries_in_the_Last_6_Months+ Loan_Purpose_major_purchase', data=train).fit()

print(model.summary2())
# Out:
#                             Results: Ordinary least squares
# ========================================================================================
# Model:                      OLS                     Adj. R-squared:            0.766
# Dependent Variable:         Interest_Rate           AIC:                       6554.9856
# Date:                       2025-07-15 14:53        BIC:                       6677.6451
# No. Observations:           1530                    Log-Likelihood:            -3254.5
# Df Model:                   22                      F-statistic:               228.0
# Df Residuals:               1507                    Prob (F-statistic):        0.00
# R-squared:                  0.769                   Scale:                     4.1850
# ----------------------------------------------------------------------------------------
#                                          Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# ----------------------------------------------------------------------------------------
# Intercept                               67.4050   1.2383  54.4335 0.0000 64.9761 69.8340
# Loan_Purpose_educational[T.True]         0.8716   0.6326   1.3778 0.1685 -0.3692  2.1124
# Loan_Purpose_house[T.True]               0.8178   0.5905   1.3847 0.1663 -0.3406  1.9761
# State_MS[T.True]                         1.9246   2.3825   0.8078 0.4193 -2.7487  6.5978
# Loan_Purpose_other[T.True]               0.5943   0.2946   2.0172 0.0439  0.0164  1.1723
# Loan_Purpose_credit_card[T.True]        -0.2019   0.2594  -0.7784 0.4365 -0.7106  0.3069
# Home_Ownership_RENT[T.True]              0.2413   0.1114   2.1659 0.0305  0.0228  0.4598
# State_IN[T.True]                        -1.0731   1.4525  -0.7388 0.4601 -3.9222  1.7760
# Loan_Purpose_small_business[T.True]      0.4650   0.3644   1.2758 0.2022 -0.2499  1.1798
# State_SD[T.True]                         1.2039   1.1874   1.0139 0.3108 -1.1252  3.5330
# Loan_Purpose_debt_consolidation[T.True] -0.0994   0.2356  -0.4219 0.6731 -0.5616  0.3628
# Home_Ownership_OTHER[T.True]             1.1453   1.1858   0.9659 0.3343 -1.1806  3.4712
# State_MT[T.True]                        -0.9518   1.0295  -0.9245 0.3554 -2.9712  1.0676
# Loan_Purpose_home_improvement[T.True]    0.1273   0.3036   0.4194 0.6750 -0.4682  0.7228
# Loan_Purpose_moving[T.True]              1.1413   0.5307   2.1507 0.0317  0.1004  2.1823
# Loan_Purpose_major_purchase[T.True]      0.4970   0.3529   1.4085 0.1592 -0.1952  1.1892
# Loan_Length                              0.1324   0.0059  22.4846 0.0000  0.1208  0.1439
# Fico_Mean                               -0.0876   0.0016 -54.3666 0.0000 -0.0908 -0.0845
# Debt_To_Income_Ratio                    -0.0009   0.0075  -0.1223 0.9027 -0.0156  0.0137
# Amount_Requested                         0.0001   0.0000   1.9910 0.0467  0.0000  0.0001
# Revolving_CREDIT_Balance                -0.0000   0.0000  -3.3226 0.0009 -0.0000 -0.0000
# Amount_Funded_By_Investors               0.0001   0.0000   3.8079 0.0001  0.0001  0.0002
# Inquiries_in_the_Last_6_Months           0.3792   0.0472   8.0283 0.0000  0.2866  0.4719
# ----------------------------------------------------------------------------------------
# Omnibus:                      82.891              Durbin-Watson:                 1.958
# Prob(Omnibus):                0.000               Jarque-Bera (JB):              119.001
# Skew:                         0.474               Prob(JB):                      0.000
# Kurtosis:                     3.985               Condition No.:                 1276885
# ========================================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly
# specified.
# [2] The condition number is large, 1.28e+06. This might indicate                that
# there are strong multicollinearity or other numerical                problems.

# %% [markdown]
# ## Now reducing Variables on basis of P-value:

# %%
model = smf.ols('Interest_Rate ~ Loan_Length+ Fico_Mean + Amount_Funded_By_Investors+ Inquiries_in_the_Last_6_Months', data=train).fit()

print(model.summary2())
# Out:
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                   OLS                  Adj. R-squared:         0.760
# Dependent Variable:      Interest_Rate        AIC:                    6574.8807
# Date:                    2025-07-15 14:53     BIC:                    6601.5458
# No. Observations:        1530                 Log-Likelihood:         -3282.4
# Df Model:                4                    F-statistic:            1210.
# Df Residuals:            1525                 Prob (F-statistic):     0.00
# R-squared:               0.760                Scale:                  4.2895
# -------------------------------------------------------------------------------
#                                 Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# -------------------------------------------------------------------------------
# Intercept                      66.4861   1.0977  60.5663 0.0000 64.3329 68.6393
# Loan_Length                     0.1374   0.0059  23.3930 0.0000  0.1259  0.1490
# Fico_Mean                      -0.0864   0.0015 -57.1600 0.0000 -0.0894 -0.0834
# Amount_Funded_By_Investors      0.0001   0.0000  18.9288 0.0000  0.0001  0.0002
# Inquiries_in_the_Last_6_Months  0.4059   0.0469   8.6613 0.0000  0.3140  0.4979
# -------------------------------------------------------------------------------
# Omnibus:                  100.349           Durbin-Watson:              1.974
# Prob(Omnibus):            0.000             Jarque-Bera (JB):           156.343
# Skew:                     0.518             Prob(JB):                   0.000
# Kurtosis:                 4.174             Condition No.:              299447
# ===============================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# [2] The condition number is large, 2.99e+05. This might indicate
# that there are strong multicollinearity or other numerical
# problems.

# %% [markdown]
# ## 4: Post Model

# %%
train['pred'] = model.predict(train)

train.head(3)
# Out:
#       State_SD  State_IN  Debt_To_Income_Ratio  State_MT  \
# 1828     False     False                 20.09     False
# 1685     False     False                 28.77     False
# 1696     False     False                 19.93     False
#
#       Loan_Purpose_educational  Revolving_CREDIT_Balance  \
# 1828                     False                   31220.0
# 1685                     False                       0.0
# 1696                     False                   22876.0
#
#       Loan_Purpose_home_improvement  Home_Ownership_OTHER  \
# 1828                          False                 False
# 1685                          False                 False
# 1696                          False                 False
#
#       Loan_Purpose_moving  State_MS  ...  Fico_Mean  \
# 1828                False     False  ...      732.0
# 1685                False     False  ...      752.0
# 1696                False     False  ...      757.0
#
#       Amount_Funded_By_Investors  Loan_Purpose_credit_card  \
# 1828                     19775.0                      True
# 1685                      5000.0                     False
# 1696                     22500.0                     False
#
#       Loan_Purpose_major_purchase  Loan_Purpose_small_business  \
# 1828                        False                        False
# 1685                        False                        False
# 1696                        False                        False
#
#       Inquiries_in_the_Last_6_Months  Amount_Requested  Loan_Purpose_other  \
# 1828                             0.0           19800.0               False
# 1685                             1.0            5000.0               False
# 1696                             0.0           22500.0                True
#
#       Interest_Rate       pred
# 1828          13.23  11.010102
# 1685           9.91   7.580582
# 1696           7.90   9.238807
#
# [3 rows x 24 columns]

# %%
test['pred'] = model.predict(test)

test.head(3)
# Out:
#       State_SD  State_IN  Debt_To_Income_Ratio  State_MT  \
# 237      False     False                  8.70     False
# 1402     False     False                 27.50     False
# 597      False     False                 29.51     False
#
#       Loan_Purpose_educational  Revolving_CREDIT_Balance  \
# 237                      False                    6215.0
# 1402                     False                   18813.0
# 597                      False                   23616.0
#
#       Loan_Purpose_home_improvement  Home_Ownership_OTHER  \
# 237                           False                 False
# 1402                          False                 False
# 597                           False                 False
#
#       Loan_Purpose_moving  State_MS  ...  Fico_Mean  \
# 237                 False     False  ...      752.0
# 1402                False     False  ...      697.0
# 597                 False     False  ...      732.0
#
#       Amount_Funded_By_Investors  Loan_Purpose_credit_card  \
# 237                       8400.0                      True
# 1402                     14000.0                     False
# 597                      14600.0                      True
#
#       Loan_Purpose_major_purchase  Loan_Purpose_small_business  \
# 237                         False                        False
# 1402                        False                         True
# 597                         False                        False
#
#       Inquiries_in_the_Last_6_Months  Amount_Requested  Loan_Purpose_other  \
# 237                              0.0            8400.0               False
# 1402                             3.0           14000.0               False
# 597                              1.0           14600.0               False
#
#       Interest_Rate       pred
# 237            5.99   7.659606
# 1402          14.09  14.428181
# 597            9.76  10.677895
#
# [3 rows x 24 columns]

# %%
from sklearn import metrics
import scipy.stats as stats

# %%
MAPE_train = round(np.mean(np.abs((train.Interest_Rate - train.pred)/train.Interest_Rate))*100,2)
print('MAPE_train',MAPE_train)

MSE_train = metrics.mean_squared_error(train.Interest_Rate , train.pred)
print('MSE_train',MSE_train)

Corr_train = stats.stats.pearsonr(train.Interest_Rate , train.pred)
print('Corr_train',Corr_train)
# Out:
# MAPE_train 13.86
# MSE_train 4.275472430335734
# Corr_train PearsonRResult(statistic=np.float64(0.8720054412311915), pvalue=np.float64(0.0))

# %%
MAPE_test = round(np.mean(np.abs((test.Interest_Rate - test.pred)/test.Interest_Rate))*100,2)
print('MAPE_test',MAPE_test)

MSE_test = metrics.mean_squared_error(test.Interest_Rate , test.pred)
print('MSE_test',MSE_test)

Corr_test = stats.stats.pearsonr(test.Interest_Rate , test.pred)
print('Corr_test',Corr_test)
# Out:
# MAPE_test 13.21
# MSE_test 3.898888696984716
# Corr_test PearsonRResult(statistic=np.float64(0.8721475413708413), pvalue=np.float64(3.178784713248761e-205))

# %%
from sklearn.metrics import r2_score
print(r2_score(test.Interest_Rate, test.pred))
# Out:
# 0.7605553853856828

# %%
import pickle
import joblib      # optional but fast for large objects
import pandas as pd

# -------------------------------------------------
# 1️⃣  Save the fitted model
# -------------------------------------------------
with open("interest_rate_model.pkl", "wb") as f:
    pickle.dump(model, f)        # or joblib.dump(model, f)

# -------------------------------------------------
# 2️⃣  Save the exact column order expected at inference
# -------------------------------------------------
feature_cols = features2.columns.tolist()
with open("feature_columns.pkl", "wb") as f:
    pickle.dump(feature_cols, f)

print("✅ Saved: interest_rate_model.pkl  and  feature_columns.pkl")
# Out:
# ✅ Saved: interest_rate_model.pkl  and  feature_columns.pkl
